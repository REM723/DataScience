# %% [markdown]
# # Learning Jupyter

# %% [markdown]
# ## Printing Name

# %%
print("Ryan")

# %% [markdown]
# ## Printing number

# %%
print(5)
# Out:
# 5

# %% [markdown]
# ## Printing Characters

# %%
print("$")
# Out:
# $
