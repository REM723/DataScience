# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_excel(r"C:\Users\ryan.e\Documents\DataScience\Students.xlsx")

# %%
#1 understanding the data

# %%
data.head()
# Out:
#    Gender Race/Ethnicity Parental Level of Education           Lunch  \
# 0  Female          Asian               Matriculation  Not Applicable
# 1  Female          Asian               Matriculation  Not Applicable
# 2    Male       European         Professional Degree            Free
# 3    Male       European             Post-Graduation  Not Applicable
# 4    Male        African                Intermediate  Not Applicable
#
#   Test Preparation Course  Math Score  Reading Score  Writing Score
# 0                     NaN          87             62             90
# 1               Completed          35             97             77
# 2                     NaN          64             58             63
# 3               Completed          64             94             19
# 4                     NaN          57             51             61

# %%
data.tail()
# Out:
#     Gender Race/Ethnicity Parental Level of Education           Lunch  \
# 95    Male       European                Intermediate        No Lunch
# 96  Female        African         Professional Degree      Subsidized
# 97    Male       European                 Arts Degree  Not Applicable
# 98    Male        African              Science Degree            Free
# 99  Female          Asian              Science Degree        No Lunch
#
#    Test Preparation Course  Math Score  Reading Score  Writing Score
# 95                     NaN          63             94             15
# 96                     NaN          35             32             83
# 97               Completed          35             44             50
# 98               Completed          65             51             18
# 99                     NaN          98             78             52

# %%
data.shape
# Out:
# (100, 8)

# %%
data.describe()
# Out:
#        Math Score  Reading Score  Writing Score
# count  100.000000     100.000000     100.000000
# mean    65.400000      62.770000      55.570000
# std     21.339961      22.203765      26.071097
# min     31.000000      27.000000      11.000000
# 25%     45.500000      43.000000      34.500000
# 50%     66.000000      60.500000      54.000000
# 75%     85.250000      84.000000      80.250000
# max     99.000000      97.000000      95.000000

# %%
data.columns
# Out:
# Index(['Gender', 'Race/Ethnicity', 'Parental Level of Education', 'Lunch',
#        'Test Preparation Course', 'Math Score', 'Reading Score',
#        'Writing Score'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Gender                          2
# Race/Ethnicity                  4
# Parental Level of Education     6
# Lunch                           4
# Test Preparation Course         1
# Math Score                     54
# Reading Score                  52
# Writing Score                  64
# dtype: int64

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
#Cleaning the Data

# %%
data.isnull().sum()
# Out:
# Gender                          0
# Race/Ethnicity                  0
# Parental Level of Education     0
# Lunch                           0
# Test Preparation Course        51
# Math Score                      0
# Reading Score                   0
# Writing Score                   0
# dtype: int64

# %%
student = data.drop(['Race/Ethnicity','Parental Level of Education','Test Preparation Course'],axis=1)

# %%
student.head()
# Out:
#    Gender           Lunch  Math Score  Reading Score  Writing Score
# 0  Female  Not Applicable          87             62             90
# 1  Female  Not Applicable          35             97             77
# 2    Male            Free          64             58             63
# 3    Male  Not Applicable          64             94             19
# 4    Male  Not Applicable          57             51             61

# %%
#Relationship Analysis

# %%
corelation = student.corr(numeric_only=True)

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(student)

# %%
for col in student.columns:
    print(repr(col))
# Out:
# 'Gender'
# 'Lunch'
# 'Math Score'
# 'Reading Score'
# 'Writing Score'

# %%
sns.relplot(x= 'Math Score', y='Reading Score', hue='Lunch',data=student)

# %%
sns.displot(student['Writing Score'], bins=5)

# %%
sns.catplot(x='Math Score',kind='box',data= student)
