# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data = {
    'students' : ["Amit", "Ryan", "Jacob", "David", "Steve"],
    'rank' : [1,4,3,5,2],
    'marks' : [95,70,80,60,90]
}

res = pd.DataFrame(data)
print("Student Records\n\n",res)
# Out:
# Student Records
#
#    students  rank  marks
# 0     Amit     1     95
# 1     Ryan     4     70
# 2    Jacob     3     80
# 3    David     5     60
# 4    Steve     2     90
